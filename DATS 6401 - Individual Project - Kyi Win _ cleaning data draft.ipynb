# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

# %%
dfedex = pd.read_csv('edex2.csv', index_col = 0)

# %%
dfedex
# Out:
#                                                                  Unnamed: 1  \
# Country
# Afghanistan                                                             NaN
# Åland Islands                                                           NaN
# Albania                                                                 NaN
# Algeria                                                                 NaN
# American Samoa                                                          NaN
# Andorra                                                                 NaN
# Angola                                                                  NaN
# Anguilla                                                                NaN
# Antigua and Barbuda                                                     NaN
# Argentina                                                               NaN
# Armenia                                                                 NaN
# ...

# %%
rr = dfedex.loc[['USA','UK','Germany','Russia','France','Italy','India','Brazil','Spain','Canada','Australia', 'Mexico','China', 'South Korea','Japan','Indonesia','Turkey','Netherlands','Switzerland','Saudi Arabia'],['2006','2007','2008','2009','2010','2011','2012','2013','2014']]
rr
# Out:
#                  2006     2007     2008     2009     2010     2011     2012  \
# Country
# USA                ..       ..       ..       ..  5.42001   5.2239  5.19486
# UK            5.02086   4.9534  4.93553  5.13067  5.77046  5.67333       ..
# Germany        4.2793  4.34303  4.40954  4.88048  4.91368   4.8078  4.93331
# Russia        3.86626       ..  4.10175       ..       ..       ..  3.78973
# France        5.44211  5.44519  5.44403  5.73849  5.68342  5.51584  5.46132
# Italy         4.53777  4.11852  4.40287  4.53631  4.35239  4.14407       ..
# India         3.18745       ..       ..  3.31124  3.42347  3.83972   3.8675
# Brazil         4.8706  4.97426  5.26884  5.46355   5.6488  5.73741   5.8551
# Spain         4.16759  4.23332  4.50094  4.86771  4.81912  4.86633  4.43188
# Canada             ..  4.78036  4.63826  4.85264  5.36993  5.27444       ..
# Australia     4.74055  4.65726  4.63187  5.08932   5.5659  5.09675  4.89419
# ...

# %%
cols =['2006','2007','2008','2009','2010','2011','2012','2013','2014']
rr[cols]= rr[cols].apply(pd.to_numeric, errors = 'coerce', axis = 1)

# %%
dfedex1 = pd.read_csv('edex1.csv', index_col = 0)
dfedex1
# Out:
#                                                                  Unnamed: 1  \
# Country
# Afghanistan                                                             NaN
# Åland Islands                                                           NaN
# Albania                                                                 NaN
# Algeria                                                                 NaN
# American Samoa                                                          NaN
# Andorra                                                                 NaN
# Angola                                                                  NaN
# Anguilla                                                                NaN
# Antigua and Barbuda                                                     NaN
# Argentina                                                               NaN
# Armenia                                                                 NaN
# ...

# %%
ss = dfedex1.loc[['USA','Germany','France','Brazil','Spain','Austria','Sweden','Australia','Norway','Denmark','Mexico','Netherlands','Switzerland'],['2006','2007','2008','2009','2010','2011','2012','2013','2014']]
ss
# Out:
#                 2006     2007     2008     2009     2010     2011     2012  \
# Country
# USA          5.38622   5.2298  5.29536  5.25621  5.42001   5.2239  5.19486
# Germany       4.2793  4.34303  4.40954  4.88048  4.91368   4.8078  4.93331
# France       5.44211  5.44519  5.44403  5.73849  5.68342  5.51584  5.46132
# Brazil        4.8706  4.97426  5.26884  5.46355   5.6488  5.73741   5.8551
# Spain        4.16759  4.23332  4.50094  4.86771  4.81912  4.86633  4.43188
# Austria      5.22652   5.1469  5.26396  5.73025  5.70048  5.59227   5.4804
# Sweden       6.41067  6.21507  6.39073  6.85779  6.62199  6.49112  7.65619
# Australia    4.74055  4.65726  4.63187  5.08932   5.5659  5.09675  4.89419
# Norway       6.38566  6.53203  6.28108  7.09544  6.74046  6.44743  7.36425
# Denmark      7.72991   7.6156  7.47605  8.44888  8.55955  8.48486  7.23782
# Mexico       4.74913  4.73198  4.85821  5.21749  5.19197   5.1462  5.16543
# ...

# %%
writer = pd.ExcelWriter('ss.xlsx')
df = ss.loc[['USA','Germany','France','Brazil','Spain','Austria','Sweden','Australia','Norway','Denmark','Mexico','Netherlands','Switzerland'],['2006','2007','2008','2009','2010','2011','2012','2013','2014']]  # C is the matrix and ind is the list of corresponding indices 
df.to_excel(writer, startcol = 0, startrow = 0)

worksheet = writer.sheets['Sheet1']
worksheet.write_string(0, 0, 'Your text here')

writer.save()

# %%
dfedex3 = pd.read_csv('edex3.csv', index_col = 0)

# %%
dfedex3
# Out:
#                                                    Country Code  \
# Country Name
# Aruba                                                       ABW
# Afghanistan                                                 AFG
# Angola                                                      AGO
# Albania                                                     ALB
# Andorra                                                     AND
# Arab World                                                  ARB
# United Arab Emirates                                        ARE
# Argentina                                                   ARG
# Armenia                                                     ARM
# American Samoa                                              ASM
# Antigua and Barbuda                                         ATG
# Australia                                                   AUS
# Austria                                                     AUT
# ...

# %%
tt = dfedex3.loc[['USA','UK','Germany','Russia','France','Italy','India','Brazil','Spain','Canada','Australia', 'Mexico','China', 'South Korea','Japan','Indonesia','Turkey','Netherlands','Switzerland','Saudi Arabia'],['2006','2007','2008','2009','2010','2011','2012','2013','2014']]
tt
# Out:
#                  2006     2007     2008     2009     2010     2011     2012  \
# Country Name
# USA           5.38623  5.22984  5.29536  5.25622  5.42707  5.21150  5.20087
# UK            5.04410  4.96506  4.95671  5.17167  5.80666  5.70902      NaN
# Germany       4.28512  4.34862  4.41254  4.88104  4.91379  4.81336  4.93020
# Russia        3.86873      NaN  4.09945      NaN      NaN      NaN  3.86133
# France        5.45172  5.43310  5.43274  5.73558  5.67910  5.51393  5.52535
# Italy         4.53330  4.11737  4.40868  4.54463  4.36467  4.13766      NaN
# India         3.09355      NaN      NaN  3.31076  3.42416  3.83866  3.86588
# Brazil        4.86949  4.97474  5.26851  5.46853  5.64277  5.74579  5.79516
# Spain         4.15923  4.23648  4.48577  4.86344  4.82330  4.86837  4.43109
# Canada            NaN  4.78744  4.64870  4.86124  5.36092  5.28122      NaN
# Australia     4.74273  4.64632  4.62719  5.08641  5.55523  5.09834  4.89991
# ...

# %%
rr['Total']= np.sum(rr, axis = 1)
rr['Total']
# Out:
# Country
# USA             6156286.0
# UK               547290.0
# Germany          357357.0
# Russia           422825.0
# France           485059.0
# Italy            283558.0
# India            406825.0
# Brazil           203687.0
# Spain            150412.0
# Canada           150436.0
# Australia        181827.0
# Mexico            50366.7
# China           1303333.0
# South Korea      280495.0
# Japan            368626.0
# Indonesia         42131.0
# Turkey           131188.0
# Netherlands       89241.0
# Switzerland       40322.0
# Saudi Arabia     518529.0
# Name: Total, dtype: float64

# %%
rr
# Out:
#                   2006      2007      2008      2009      2010      2011  \
# Country
# USA           620387.0  636674.0  683776.0  738621.0  758890.0  749533.0
# UK             59720.0   61610.0   64360.0   65610.0   64230.0   61518.0
# Germany        38331.0   38364.0   39467.0   40958.0   41405.0   40221.0
# Russia         34633.0   37698.0   41423.0   43458.0   44338.0   47321.0
# France         53957.0   54164.0   53622.0   57240.0   54623.0   53288.0
# Italy          34174.0   33114.0   34326.0   33363.0   32422.0   31815.0
# India          35747.0   36179.0   41036.0   48315.0   48508.0   48978.0
# Brazil         17914.0   19320.0   20556.0   22414.0   24890.0   24110.0
# Spain          17642.0   18298.0   18197.0   17469.0   17582.0   16220.0
# Canada         15234.0   16609.0   17900.0   18717.0   16905.0   17477.0
# Australia      17800.0   18893.0   19582.0   21047.0   21306.0   21011.0
# Mexico          4018.7    4538.0    4543.0    5149.0    5615.0    5858.0
# ...

# %%
writer = pd.ExcelWriter('rr.xlsx')
df = rr.loc[['USA','UK','Germany','Russia','France','Italy','India','Brazil','Spain','Canada','Australia', 'Mexico','China', 'South Korea','Japan','Indonesia','Turkey','Netherlands','Switzerland','Saudi Arabia'],['2006','2007','2008','2009','2010','2011','2012','2013','2014','Total']]  # C is the matrix and ind is the list of corresponding indices 
df.to_excel(writer, startcol = 0, startrow = 0)

worksheet = writer.sheets['Sheet1']
worksheet.write_string(0, 0, 'Your text here')

writer.save()

# %%
gdppp = pd.read_csv('gdppp.csv', index_col = 0)
gdppp
# Out:
#                                                    Country Code  \
# Country Name
# Aruba                                                       ABW
# Afghanistan                                                 AFG
# Angola                                                      AGO
# Albania                                                     ALB
# Andorra                                                     AND
# Arab World                                                  ARB
# United Arab Emirates                                        ARE
# Argentina                                                   ARG
# Armenia                                                     ARM
# American Samoa                                              ASM
# Antigua and Barbuda                                         ATG
# Australia                                                   AUS
# Austria                                                     AUT
# ...

# %%
gdpppe = gdppp.loc[['USA','Germany','France','Brazil','Spain','Austria','Sweden','Australia','Norway','Denmark','Mexico','Netherlands','Switzerland'],['2006','2007','2008','2009','2010','2011','2012','2013','2014']]
gdpppe
# Out:
#                       2006          2007          2008          2009  \
# Country Name
# USA           46437.067120  48061.537660  48401.427340  47001.555350
# Germany       36447.872320  41814.819100  45699.198320  41732.707250
# France        36544.505660  41600.585270  45413.066420  41631.131410
# Brazil         5860.145975   7313.557962   8787.610375   8553.380470
# Spain         28482.609480  32709.401040  35579.309930  32334.005480
# Austria       40635.281820  46855.771750  51708.765750  47963.179400
# Sweden        46256.471600  53324.379370  55746.842380  46207.059200
# Australia     36118.283810  40991.982890  49664.685040  42742.998980
# Norway        74114.697150  85170.862170  97007.941890  80067.176640
# Denmark       52026.993110  58487.045010  64322.066640  58163.293590
# Mexico         8767.920258   9330.341687   9689.052887   7748.123301
# Netherlands   44453.971190  51241.315620  56928.820480  51900.340090
# ...

# %%
writer = pd.ExcelWriter('gdpppe.xlsx')
df = gdpppe.loc[['USA','Germany','France','Brazil','Spain','Austria','Sweden','Australia','Norway','Denmark','Mexico','Netherlands','Switzerland'],['2006','2007','2008','2009','2010','2011','2012','2013','2014']]# ind is the list of corresponding indices 
df.to_excel(writer, startcol = 0, startrow = 0)

worksheet = writer.sheets['Sheet1']
worksheet.write_string(0, 0, 'Your text here')

writer.save()

# %%
totalgdp = pd.read_csv('totalgdpe.csv', index_col = 0)
totalgdp
# Out:
#                                                    Country Code  \
# Country Name
# Aruba                                                       ABW
# Afghanistan                                                 AFG
# Angola                                                      AGO
# Albania                                                     ALB
# Andorra                                                     AND
# Arab World                                                  ARB
# United Arab Emirates                                        ARE
# Argentina                                                   ARG
# Armenia                                                     ARM
# American Samoa                                              ASM
# Antigua and Barbuda                                         ATG
# Australia                                                   AUS
# Austria                                                     AUT
# ...

# %%
totalgdpe = totalgdp.loc[['USA','Germany','France','Brazil','Spain','Austria','Sweden','Australia','Norway','Denmark','Mexico','Netherlands','Switzerland'],['2006','2007','2008','2009','2010','2011','2012','2013','2014']]
totalgdpe = totalgdpe / 1000000
totalgdpe
# Out:
#                     2006        2007        2008        2009        2010  \
# Country Name
# USA           13855900.0  14477600.0  14718600.0  14418700.0  14964400.0
# Germany        3002450.0   3439950.0   3752370.0   3418010.0   3417090.0
# France         2325010.0   2663110.0   2923470.0   2693830.0   2646840.0
# Brazil         1107640.0   1397080.0   1695820.0   1667020.0   2208870.0
# Spain          1264550.0   1479340.0   1635020.0   1499100.0   1431620.0
# Austria         335999.0    388691.0    430294.0    400172.0    391893.0
# Sweden          420032.0    487816.0    513966.0    429657.0    488378.0
# Australia       747573.0    853765.0   1055330.0    927168.0   1142880.0
# Norway          345425.0    401083.0    462554.0    386622.0    429131.0
# Denmark         282885.0    319423.0    353361.0    321241.0    321995.0
# Mexico          965281.0   1043470.0   1101280.0    894949.0   1051130.0
# Netherlands     726649.0    839420.0    936228.0    857933.0    836390.0
# ...

# %%
writer = pd.ExcelWriter('totalgdpe1.xlsx')
df = totalgdpe.loc[['USA','UK','Germany','Russia','France','Italy','India','Brazil','Spain','Canada','Australia', 'Mexico','China', 'South Korea','Japan','Indonesia','Turkey','Netherlands','Switzerland','Saudi Arabia'],['2006','2007','2008','2009','2010','2011','2012','2013','2014','Total']]  # C is the matrix and ind is the list of corresponding indices 
df.to_excel(writer, startcol = 0, startrow = 0)

worksheet = writer.sheets['Sheet1']
worksheet.write_string(0, 0, 'Your text here')

writer.save()

# %%
population = pd.read_csv('populatione.csv', index_col = 0)
population
# Out:
#                                                    Country Code  \
# Country Name
# Aruba                                                       ABW
# Afghanistan                                                 AFG
# Angola                                                      AGO
# Albania                                                     ALB
# Andorra                                                     AND
# Arab World                                                  ARB
# United Arab Emirates                                        ARE
# Argentina                                                   ARG
# Armenia                                                     ARM
# American Samoa                                              ASM
# Antigua and Barbuda                                         ATG
# Australia                                                   AUS
# Austria                                                     AUT
# ...

# %%
populatione1 = population.loc[['USA','Germany','France','Brazil','Spain','Austria','Sweden','Australia','Norway','Denmark','Mexico','Netherlands','Switzerland'],['2006','2007','2008','2009','2010','2011','2012','2013','2014']]
populatione1 = populatione1 / 1000000
populatione1
# Out:
#                     2006        2007        2008        2009        2010  \
# Country Name
# USA           298.379912  301.231207  304.093966  306.771529  309.348193
# Germany        82.376451   82.266372   82.110097   81.902307   81.776930
# France         63.621376   64.016229   64.374990   64.707044   65.027512
# Brazil        189.012412  191.026637  192.979029  194.895996  196.796269
# Spain          44.397319   45.226803   45.954106   46.362946   46.576897
# Austria         8.268641    8.295487    8.321496    8.343323    8.363404
# Sweden          9.080505    9.148092    9.219637    9.298515    9.378126
# Australia      20.697900   20.827600   21.249200   21.691700   22.031750
# Norway          4.660677    4.709153    4.768212    4.828726    4.889252
# Denmark         5.437272    5.461438    5.493621    5.523095    5.547683
# Mexico        110.092378  111.836346  113.661809  115.505228  117.318941
# Netherlands    16.346101   16.381696   16.445593   16.530388   16.615394
# ...

# %%
populationh = population.loc[['USA','UK','Germany','Russia','France','Italy','India','Brazil','Spain','Canada','Australia', 'Mexico','China', 'South Korea','Japan','Indonesia','Turkey','Netherlands','Switzerland','Saudi Arabia'],['2006','2007','2008','2009','2010','2011','2012','2013','2014']]  # C is the matrix and ind is the list of corresponding indices 
populationh = populationh/ 1000000
populationh
# Out:
#                      2006         2007         2008         2009         2010  \
# Country Name
# USA            298.379912   301.231207   304.093966   306.771529   309.348193
# UK              60.846820    61.322463    61.806995    62.276270    62.766365
# Germany         82.376451    82.266372    82.110097    81.902307    81.776930
# Russia         143.049528   142.805088   142.742350   142.785342   142.849449
# France          63.621376    64.016229    64.374990    64.707044    65.027512
# Italy           58.143979    58.438310    58.826731    59.095365    59.277417
# India         1161.977719  1179.681239  1197.146906  1214.270132  1230.980691
# Brazil         189.012412   191.026637   192.979029   194.895996   196.796269
# Spain           44.397319    45.226803    45.954106    46.362946    46.576897
# Canada          32.570505    32.887928    33.245773    33.628571    34.005274
# Australia       20.697900    20.827600    21.249200    21.691700    22.031750
# ...

# %%
writer = pd.ExcelWriter('populatione1.xlsx')
df = populatione1.loc[['USA','UK','Germany','Russia','France','Italy','India','Brazil','Spain','Canada','Australia', 'Mexico','China', 'South Korea','Japan','Indonesia','Turkey','Netherlands','Switzerland','Saudi Arabia'],['2006','2007','2008','2009','2010','2011','2012','2013','2014','Total']]  # C is the matrix and ind is the list of corresponding indices 
df.to_excel(writer, startcol = 0, startrow = 0)

worksheet = writer.sheets['Sheet1']
worksheet.write_string(0, 0, 'Your text here')

writer.save()

# %%
cols =['2006','2007','2008','2009','2010','2011','2012','2013','2014']
totalgdpe[cols]= totalgdpe[cols].apply(pd.to_numeric, errors = 'coerce', axis = 1)

# %%
cols =['2006','2007','2008','2009','2010','2011','2012','2013','2014']
ss[cols]= ss[cols].apply(pd.to_numeric, errors = 'coerce', axis = 1)

# %%
cols =['2006','2007','2008','2009','2010','2011','2012','2013','2014']
populatione1[cols]= populatione1[cols].apply(pd.to_numeric, errors = 'coerce', axis = 1)

# %%
totalgdph = totalgdp.loc[['USA','UK','Germany','Russia','France','Italy','India','Brazil','Spain','Canada','Australia', 'Mexico','China', 'South Korea','Japan','Indonesia','Turkey','Netherlands','Switzerland','Saudi Arabia'],['2006','2007','2008','2009','2010','2011','2012','2013','2014']]
totalgdph = totalgdph / 1000000
totalgdph
# Out:
#                     2006        2007        2008        2009        2010  \
# Country Name
# USA           13855900.0  14477600.0  14718600.0  14418700.0  14964400.0
# UK             2692610.0   3074360.0   2890560.0   2382830.0   2441170.0
# Germany        3002450.0   3439950.0   3752370.0   3418010.0   3417090.0
# Russia          989931.0   1299710.0   1660840.0   1222640.0   1524920.0
# France         2325010.0   2663110.0   2923470.0   2693830.0   2646840.0
# Italy          1942630.0   2203050.0   2390730.0   2185160.0   2125060.0
# India           920317.0   1201110.0   1186950.0   1323940.0   1656620.0
# Brazil         1107640.0   1397080.0   1695820.0   1667020.0   2208870.0
# Spain          1264550.0   1479340.0   1635020.0   1499100.0   1431620.0
# Canada         1315420.0   1464980.0   1549130.0   1371150.0   1613460.0
# Australia       747573.0    853765.0   1055330.0    927168.0   1142880.0
# Mexico          965281.0   1043470.0   1101280.0    894949.0   1051130.0
# ...

# %%
totalhs = (totalgdph * hegdp)/100
totalhs
# Out:
#                       2006          2007          2008          2009  \
# Country Name
# USA           2.115802e+06  2.253590e+06  2.358304e+06  2.451055e+06
# UK            2.251900e+05  2.587424e+05  2.558405e+05  2.337546e+05
# Germany       3.104834e+05  3.502009e+05  3.899638e+05  3.897644e+05
# Russia        5.251373e+04  6.992379e+04  1.033806e+05  9.100416e+04
# France        2.448054e+05  2.782680e+05  3.090070e+05  3.038800e+05
# Italy         1.713106e+05  1.868558e+05  2.124367e+05  2.057306e+05
# India         3.908293e+04  5.076529e+04  5.150761e+04  5.793214e+04
# Brazil        9.255116e+04  1.156865e+05  1.397015e+05  1.441822e+05
# Spain         1.041052e+05  1.236377e+05  1.439629e+05  1.427353e+05
# Canada        1.282637e+05  1.440791e+05  1.554005e+05  1.531999e+05
# Australia     6.347784e+04  7.283154e+04  9.269487e+04  8.387214e+04
# Mexico        5.629691e+04  6.172792e+04  6.675211e+04  5.902904e+04
# ...

# %%
pphs = totalhs / populationh
pphs
# Out:
#                      2006         2007         2008         2009         2010  \
# Country Name
# USA           7090.966072  7481.261898  7755.181450  7989.839793  8231.681392
# UK            3700.932953  4219.373855  4139.345171  3753.509529  3697.565573
# Germany       3769.079302  4256.913774  4749.279948  4758.893948  4701.520746
# Russia         367.101710   489.644963   724.246217   637.349473   729.200772
# France        3847.848648  4346.836017  4800.109195  4696.243225  4557.647540
# Italy         2946.317903  3197.487678  3611.226728  3481.331470  3376.982209
# India           33.634836    43.033056    43.025301    47.709432    57.594755
# Brazil         489.656497   605.603841   723.920506   739.790355   927.941567
# Spain         2344.853492  2733.725216  3132.754525  3078.650893  2937.119184
# Canada        3938.031031  4380.910942  4674.292513  4555.645812  5314.640293
# Australia     3066.873617  3496.876140  4362.275713  3866.554310  4676.602612
# ...

# %%
writer = pd.ExcelWriter('pphs.xlsx')
df = pphs.loc[['USA','UK','Germany','Russia','France','Italy','India','Brazil','Spain','Canada','Australia', 'Mexico','China', 'South Korea','Japan','Indonesia','Turkey','Netherlands','Switzerland','Saudi Arabia'],['2006','2007','2008','2009','2010','2011','2012','2013','2014']]  # C is the matrix and ind is the list of corresponding indices 
df.to_excel(writer, startcol = 0, startrow = 0)

worksheet = writer.sheets['Sheet1']
worksheet.write_string(0, 0, 'Your text here')

writer.save()

# %%
totales = (totalgdpe * ss) / 100
totales
# Out:
#                        2006           2007           2008           2009  \
# Country Name
# USA           746309.256980  757149.524800  779402.856960  757877.151270
# Germany       128483.842850  149398.060485  165462.256098  166815.294448
# France        126529.601711  145011.399409  159154.583841  154585.165167
# Brazil         53948.713840   69494.391608   89350.042488   91078.471210
# Spain          52701.259345   62625.196088   73591.269188   72971.840610
# Austria        17561.054935   20005.537079   22650.504042   22930.856030
# Sweden         26926.865414   30318.105871   32846.179352   29464.974780
# Australia      35439.071851   39762.055839   48881.513671   47186.546458
# Norway         22057.666055   26198.861885   29053.386783   27432.532037
# Denmark        21866.755904   24325.977988   26417.445041   27141.266601
# Mexico         45842.449555   49376.791706   53502.495088   46693.874580
# Netherlands    36989.849350   41414.968192   47675.257576   47150.196021
# ...

# %%
writer = pd.ExcelWriter('totales.xlsx')
df = totales.loc[['USA','Germany','France','Brazil','Spain','Austria','Sweden','Australia','Norway','Denmark','Mexico','Netherlands','Switzerland'],['2006','2007','2008','2009','2010','2011','2012','2013','2014']]# ind is the list of corresponding indices 
df.to_excel(writer, startcol = 0, startrow = 0)

worksheet = writer.sheets['Sheet1']
worksheet.write_string(0, 0, 'Your text here')

writer.save()

# %%
ppes = totales/ populatione1
ppes
# Out:
#                      2006         2007         2008         2009         2010  \
# Country Name
# USA           2501.204763  2513.516220  2563.032957  2470.493770  2621.873975
# Germany       1559.715687  1816.028310  2015.126789  2036.759410  2053.205811
# France        1988.790713  2265.228703  2472.304599  2389.000573  2313.344449
# Brazil         285.424186   363.794247   463.003897   467.318329   634.029543
# Spain         1187.036977  1384.692084  1601.407917  1573.925881  1481.238343
# Austria       2123.813930  2411.616953  2721.926928  2748.408042  2671.135113
# Sweden        2965.348889  3314.145274  3562.632602  3168.782841  3448.486651
# Australia     1712.206159  1909.104066  2300.393129  2175.327266  2887.267599
# Norway        4732.717169  5563.391524  6093.140738  5681.111754  5916.120380
# Denmark       4021.640982  4454.134239  4808.749100  4914.140822  4968.078209
# Mexico         416.399849   441.509344   470.716554   404.257672   465.179397
# ...

# %%
writer = pd.ExcelWriter('ppes.xlsx')
df = ppes.loc[['USA','Germany','France','Brazil','Spain','Austria','Sweden','Australia','Norway','Denmark','Mexico','Netherlands','Switzerland'],['2006','2007','2008','2009','2010','2011','2012','2013','2014']]# ind is the list of corresponding indices 
df.to_excel(writer, startcol = 0, startrow = 0)

worksheet = writer.sheets['Sheet1']
worksheet.write_string(0, 0, 'Your text here')

writer.save()

# %%
dfhegdp = pd.read_csv('hegdp.csv', index_col = 0)
dfhegdp
# Out:
#                    2006       2007       2008       2009       2010  \
# Country
# USA           15.270043  15.566044  16.022610  16.999143  17.016758
# UK             8.363261   8.416139   8.850897   9.809956   9.507029
# Germany       10.341001  10.180405  10.392468  11.403255  11.251560
# Russia         5.304787   5.379953   6.224598   7.443251   6.830911
# France        10.529220  10.448988  10.569870  11.280594  11.197219
# Italy          8.818491   8.481686   8.885849   9.414897   9.419912
# India          4.246681   4.226531   4.339492   4.375737   4.279680
# Brazil         8.355707   8.280590   8.237990   8.649097   8.267369
# Spain          8.232589   8.357622   8.804965   9.521401   9.555741
# Canada         9.750776   9.834884  10.031467  11.173093  11.201133
# Australia      8.491190   8.530630   8.783496   9.046056   9.015272
# Mexico         5.832178   5.915639   6.061321   6.595800   6.394443
# China          4.522417   4.318333   4.589052   5.075355   4.886340
# ...

# %%
hegdp = dfhegdp.loc[['USA','UK','Germany','Russia','France','Italy','India','Brazil','Spain','Canada','Australia', 'Mexico','China', 'South Korea','Japan','Indonesia','Turkey','Netherlands','Switzerland','Saudi Arabia'],['2006','2007','2008','2009','2010','2011','2012','2013','2014']]
hegdp
# Out:
#                    2006       2007       2008       2009       2010  \
# Country
# USA           15.270043  15.566044  16.022610  16.999143  17.016758
# UK             8.363261   8.416139   8.850897   9.809956   9.507029
# Germany       10.341001  10.180405  10.392468  11.403255  11.251560
# Russia         5.304787   5.379953   6.224598   7.443251   6.830911
# France        10.529220  10.448988  10.569870  11.280594  11.197219
# Italy          8.818491   8.481686   8.885849   9.414897   9.419912
# India          4.246681   4.226531   4.339492   4.375737   4.279680
# Brazil         8.355707   8.280590   8.237990   8.649097   8.267369
# Spain          8.232589   8.357622   8.804965   9.521401   9.555741
# Canada         9.750776   9.834884  10.031467  11.173093  11.201133
# Australia      8.491190   8.530630   8.783496   9.046056   9.015272
# Mexico         5.832178   5.915639   6.061321   6.595800   6.394443
# China          4.522417   4.318333   4.589052   5.075355   4.886340
# ...

# %%
dfmsud = pd.read_csv('msud.csv', index_col = 0)
dfmsud
# Out:
#                                                                       Unnamed: 1  \
# Country
# Africa                                                                       NaN
# North Africa                                                                 NaN
# Algeria                                                                      NaN
# Libya                                                                        NaN
# Morocco                                                                      NaN
# Tunisia                                                                      NaN
# Sub-Saharan                                                                  NaN
# Angola                                                                       NaN
# Benin                                                                        NaN
# Botswana                                                                     NaN
# ...

# %%
msudh = dfmsud.loc[['USA','UK','Germany','Russia','France','Italy','India','Brazil','Spain','Canada','Australia', 'Mexico','China', 'South Korea','Japan','Indonesia','Turkey','Netherlands','Switzerland','Saudi Arabia'],['2006','2007','2008','2009','2010','2011','2012','2013','2014']]
msudh
# Out:
#                 2006    2007    2008    2009    2010    2011    2012    2013  \
# Country
# USA           620387  636674  683776  738621  758890  749533  706918  650851
# UK             59720   61610   64360   65610   64230   61518   58896   56408
# Germany        38331   38364   39467   40958   41405   40221   41180   38803
# Russia         34633   37698   41423   43458   44338   47321   54832   57500
# France         53957   54164   53622   57240   54623   53288   52551   52419
# Italy          34174   33114   34326   33363   32422   31815   29554   28388
# India          35747   36179   41036   48315   48508   48978   48804   48445
# Brazil         17914   19320   20556   22414   24890   24110   24574   24708
# Spain          17642   18298   18197   17469   17582   16220   16404   14311
# Canada         15234   16609   17900   18717   16905   17477   16619   15362
# Australia      17800   18893   19582   21047   21306   21011   20275   20099
# ...

# %%
msudh['Total'] = np.sum(msudh, axis = 1)

# %%
cols =['2006','2007','2008','2009','2010','2011','2012','2013','2014']
msudh[cols]= msudh[cols].apply(pd.to_numeric, errors = 'coerce', axis = 1)

# %%
msudh
# Out:
#                   2006      2007      2008      2009      2010      2011  \
# Country
# USA           620387.0  636674.0  683776.0  738621.0  758890.0  749533.0
# UK             59720.0   61610.0   64360.0   65610.0   64230.0   61518.0
# Germany        38331.0   38364.0   39467.0   40958.0   41405.0   40221.0
# Russia         34633.0   37698.0   41423.0   43458.0   44338.0   47321.0
# France         53957.0   54164.0   53622.0   57240.0   54623.0   53288.0
# Italy          34174.0   33114.0   34326.0   33363.0   32422.0   31815.0
# India          35747.0   36179.0   41036.0   48315.0   48508.0   48978.0
# Brazil         17914.0   19320.0   20556.0   22414.0   24890.0   24110.0
# Spain          17642.0   18298.0   18197.0   17469.0   17582.0   16220.0
# Canada         15234.0   16609.0   17900.0   18717.0   16905.0   17477.0
# Australia      17800.0   18893.0   19582.0   21047.0   21306.0   21011.0
# Mexico          4018.7    4538.0    4543.0    5149.0    5615.0    5858.0
# ...

# %%
writer = pd.ExcelWriter('msudh.xlsx')
df = msudh.loc[['USA','UK','Germany','Russia','France','Italy','India','Brazil','Spain','Canada','Australia', 'Mexico','China', 'South Korea','Japan','Indonesia','Turkey','Netherlands','Switzerland','Saudi Arabia'],['2006','2007','2008','2009','2010','2011','2012','2013','2014','Total']]  # C is the matrix and ind is the list of corresponding indices 
df.to_excel(writer, startcol = 0, startrow = 0)

worksheet = writer.sheets['Sheet1']
worksheet.write_string(0, 0, 'Your text here')

writer.save()

# %%
msude = dfmsud.loc[['USA','Germany','France','Brazil','Spain','Austria','Sweden','Australia','Norway','Denmark','Mexico','Netherlands','Switzerland'],['2006','2007','2008','2009','2010','2011','2012','2013','2014']]# ind is the list of corresponding indices 
msude
# Out:
#                2006    2007    2008    2009    2010    2011    2012    2013  \
# Country
# USA          620387  636674  683776  738621  758890  749533  706918  650851
# Germany       38331   38364   39467   40958   41405   40221   41180   38803
# France        53957   54164   53622   57240   54623   53288   52551   52419
# Brazil        17914   19320   20556   22414   24890   24110   24574   24708
# Spain         17642   18298   18197   17469   17582   16220   16404   14311
# Austria        2787    3315    3212    3000    2982    2915    2877    2765
# Sweden         5379    5520    4909    4815    5210    4899    5002    5031
# Australia     17800   18893   19582   21047   21306   21011   20275   20099
# Norway         4734    5036    5063    5373    5291    5389    5487    5614
# Denmark        4023    3879    4029    3788    4033    3759    3876    3556
# Mexico       4018.7    4538    4543    5149    5615    5858    6432    6749
# ...

# %%
msude['Total'] = np.sum(msude, axis = 1)

# %%
cols =['2006','2007','2008','2009','2010','2011','2012','2013','2014']
msude[cols]= msude[cols].apply(pd.to_numeric, errors = 'coerce', axis = 1)

# %%
msude
# Out:
#                  2006      2007      2008      2009      2010      2011  \
# Country
# USA          620387.0  636674.0  683776.0  738621.0  758890.0  749533.0
# Germany       38331.0   38364.0   39467.0   40958.0   41405.0   40221.0
# France        53957.0   54164.0   53622.0   57240.0   54623.0   53288.0
# Brazil        17914.0   19320.0   20556.0   22414.0   24890.0   24110.0
# Spain         17642.0   18298.0   18197.0   17469.0   17582.0   16220.0
# Austria        2787.0    3315.0    3212.0    3000.0    2982.0    2915.0
# Sweden         5379.0    5520.0    4909.0    4815.0    5210.0    4899.0
# Australia     17800.0   18893.0   19582.0   21047.0   21306.0   21011.0
# Norway         4734.0    5036.0    5063.0    5373.0    5291.0    5389.0
# Denmark        4023.0    3879.0    4029.0    3788.0    4033.0    3759.0
# Mexico         4018.7    4538.0    4543.0    5149.0    5615.0    5858.0
# Netherlands   10526.0   10667.0   10483.0   10709.0   10258.0    9914.0
# ...

# %%
writer = pd.ExcelWriter('msude.xlsx')
df = msude.loc[['USA','Germany','France','Brazil','Spain','Austria','Sweden','Australia','Norway','Denmark','Mexico','Netherlands','Switzerland'],['2006','2007','2008','2009','2010','2011','2012','2013','2014','Total']]# ind is the list of corresponding indices 
df.to_excel(writer, startcol = 0, startrow = 0)

worksheet = writer.sheets['Sheet1']
worksheet.write_string(0, 0, 'Your text here')

writer.save()
